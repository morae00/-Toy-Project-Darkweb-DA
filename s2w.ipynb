# %%
import pandas as pd
import numpy

# %%
df = pd.read_csv("./dataset/Agora.csv", encoding="latin1")
df
# Out:
#               Vendor             Category  \
# 0         CheapPayTV     Services/Hacking
# 1         CheapPayTV     Services/Hacking
# 2          KryptykOG     Services/Hacking
# 3           cyberzen     Services/Hacking
# 4       businessdude     Services/Hacking
# ...              ...                  ...
# 109684       gonz324  Drugs/Opioids/Opium
# 109685     cheqdropz    Weapons/Fireworks
# 109686     SnowQueen  Drugs/Opioids/Opium
# 109687     SnowQueen  Drugs/Opioids/Opium
# 109688    daydreamer  Drugs/Opioids/Opium
#
#                                                      Item  \
# 0                             12 Month HuluPlus gift Code
# 1       Pay TV Sky UK  Sky Germany HD TV  and much mor...
# 2                    OFFICIAL Account Creator Extreme 4.2
# 3                               VPN > TOR > SOCK TUTORIAL
# 4                                  Facebook hacking guide
# ...                                                   ...
# ...

# %%
df2 = pd.read_excel("./dataset/mastersr2.xlsx")
df2
# Out:
#                                                     Title       Sellerid  \
# 0       Ray Ban Tech RB3460 001 Aviator/Flip Out/ Sung...       FoxyGirl
# 1       Ray Ban RB3025 Aviator Classic Sunglasses Replica       FoxyGirl
# 2                   Rolex - Watch Box (AAA Grade Replica)         RepAAA
# 3       Ray Ban RB3016 - W0365 | Clubmaster Sunglasses...       FoxyGirl
# 4          Rolex - Submariner 2Tone YG/SS Black [Replica]         RepAAA
# ...                                                   ...            ...
# 618855  Twitter , Facebook , youtube , instagram services  profesorhouse
# 618856           500,000 High Retention Views | YouTube |      SideAlley
# 618857                    25 000 Real Twitter Followers!   profesorhouse
# 618858     40,000 Facebook Followers Subscribers. >Cheap<      SideAlley
# 618859                          2000 Youtube Real Likes!   profesorhouse
#
#           PriceUSD  PriceBTC  Rating  Reviews              Origin Destination  \
# ...
